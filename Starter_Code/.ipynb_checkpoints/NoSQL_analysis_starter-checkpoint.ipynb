# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': {'$eq': 20}}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print("Number of documents in result: ", count)
results = establishments.find(query)
# Display the first document in the results using pprint
for i in range(1):
    pprint(results[i])
# Out:
# Number of documents in result:  41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66135c2374a576b002ff645d'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
hygiene_score_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
hygiene_rows = len(hygiene_score_df)
print("Number records in result: ", hygiene_rows)
# Display the first 10 rows of the DataFrame
hygiene_score_df.head(10)
# Out:
# Number records in result:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  66135c2374a576b002ff645d   110681                  0
# 1  66135c2374a576b002ff67dc   612039                  0
# 2  66135c2374a576b002ff6ae9   730933                  0
# 3  66135c2374a576b002ff6cd5   172735                  0
# 4  66135c2374a576b002ff6ce1   172953                  0
# 5  66135c2374a576b002ff7684   512854                  0
# 6  66135c2374a576b002ff78a5  1537089                  0
# 7  66135c2374a576b002ff8dd0   155648                  0
# 8  66135c2374a576b002ff9213  1012883                  0
# 9  66135c2374a576b002ff9a26   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query_1 = {'LocalAuthorityName': {'$regex': "London"}, 'RatingValue': {'$gte': 4}}

# Use count_documents to display the number of documents in the result
count_1 = establishments.find(query_1)
print("Number records in result: ", establishments.count_documents(count_1))

# Display the first document in the results using pprint
pprint(count_1)
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# Cell In[8], line 6
#       4 # Use count_documents to display the number of documents in the result
#       5 count_1 = establishments.find(query_1)
# ----> 6 print("Number records in result: ", establishments.count_documents(count_1))
#       8 # Display the first document in the results using pprint
#       9 pprint(count_1)
#
# File ~\anaconda3\envs\dev\Lib\site-packages\pymongo\collection.py:1826, in Collection.count_documents(self, filter, session, **kwargs)
#    1823         return 0
#    1824     return result['n']
# -> 1826 return self.__database.client._retryable_read(
#    1827     _cmd, self._read_preference_for(session), session)
#
# File ~\anaconda3\envs\dev\Lib\site-packages\pymongo\mongo_client.py:1525, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
# ...

# %%
# Convert the result to a Pandas DataFrame
local_auth_rating_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
local_auth_rating_rows = len(local_auth_rating_df)
print("Number records in result: ", local_auth_rating_rows)

# Display the first 10 rows of the DataFrame
local_auth_rating_df.head(10)
# Out:
# Number records in result:  0
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.490142
longitude = 0.08384

query = {'RatingValue': '5', 
         'geocode.latitude': {'$lte': (latitude + degree_search), '$gte': (latitude - degree_search)}, 
         'geocode.longitude': {'$lte': (longitude + degree_search), '$gte': (longitude - degree_search)} 
         }
sort = [('scores.Hygiene', 1)]

# Print the results
for result in establishments.find(query).sort(sort).limit(5):
    pprint(result)

# %%
# Convert result to Pandas DataFrame
pd.DataFrame(establishments.find(query).sort(sort).limit(5))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': {'$eq': 0}}}
# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id': "$LocalAuthorityName", 'count': { '$sum': 1 }}}
# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': { 'count': -1 }}
pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))
# Print the number of documents in the result
results = list(establishments.aggregate(pipeline))
# Print the first 10 results
print("Number of establishments in result: ", len(results))
# Out:
# Number of establishments in result:  55

# %%
# Convert the result to a Pandas DataFrame
grouped_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Number records in result: ", len(grouped_df))

# Display the first 10 rows of the DataFrame
grouped_df.head(10)
# Out:
# Number records in result:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
